# %% [markdown]
# #

# %% [markdown]
# # Transfer Learning on kermany18 OCT dataset using VGG16
#
# We attempt to perform classification on the RET OCT2017 (kermany18) dataset by leveraging transfer learning using the VGG16 model pretrained on imagenet. We freeze all the layers except the top and train on the dataset using class weights to prevent class imbalance.
#
# Dataset consists of 4 classes: CNV, DME, DRUSEN, NORMAL
#
# Due to large amount of data having white patches and unequal sizes, we only extract images without these artifacts. To prevent extreme imbalance we only extract around 1000 images per class for train set and around 200 for test set.
#
# Our observations are that model overfits to the data, giving 85% test set accuracy.
# We display classification report, accuracy and loss graphs, ros curves for each class and confusion matrix.

# %%
import os
import pandas as pd
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import random
from collections import defaultdict
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import json
from datetime import datetime

# %% [markdown]
# ### Loading the dataset

# %%
train_path = "/kaggle/input/kermany2018/OCT2017 /train"
test_path = "/kaggle/input/kermany2018/OCT2017 /test"
dir_name = os.listdir(train_path)

# %%
train = defaultdict(list)
test = defaultdict(list)
train_label = defaultdict(list)
test_label = defaultdict(list)

from tqdm import tqdm
for i in range(4):
    path = os.path.join(train_path, dir_name[i])
    for j in tqdm(os.listdir(path)):
        im = np.array(Image.open(os.path.join(path, j)))
        if im.shape == (496, 768):
            train[str(dir_name[i])].append(os.path.join(path, j))
            train_label[str(dir_name[i])].append(dir_name[i])

for i in range(4):
    path = os.path.join(test_path, dir_name[i])
    for j in tqdm(os.listdir(path)):
        im = np.array(Image.open(os.path.join(path, j)))
        if im.shape == (496, 768):
            test[str(dir_name[i])].append(os.path.join(path, j))
            test_label[str(dir_name[i])].append(dir_name[i])
# Out:
# 100%|██████████| 8616/8616 [02:04<00:00, 69.45it/s]
# 100%|██████████| 37205/37205 [07:48<00:00, 79.46it/s]
# 100%|██████████| 26315/26315 [04:50<00:00, 90.51it/s]
# 100%|██████████| 11348/11348 [02:06<00:00, 89.83it/s]
# 100%|██████████| 242/242 [00:02<00:00, 90.25it/s]
# 100%|██████████| 242/242 [00:02<00:00, 92.69it/s]
# 100%|██████████| 242/242 [00:02<00:00, 88.60it/s]
# 100%|██████████| 242/242 [00:02<00:00, 94.62it/s]

# %%
print("Train set distribution")
for i in dir_name:
    print(i,len(train[str(i)]))
print("Test set distribution")
for i in dir_name: 
    print(i,len(test[str(i)]))
# Out:
# Train set distribution
# DRUSEN 2531
# CNV 12050
# NORMAL 6088
# DME 816
# Test set distribution
# DRUSEN 36
# CNV 65
# NORMAL 15
# DME 106

# %%
# Assigning equal amount of data per class to both train and test
train_path = []
train_class = []
test_path = []
test_class = []

for i in range(3):
    temp  = list(zip(train[dir_name[i]], train_label[dir_name[i]]))
    random.shuffle(temp)
    res1, res2 = zip(*temp)
    train_path.extend(res1[0:1000])
    train_class.extend(res2[0:1000])
    
    test_path.extend(res1[1000:1200])
    test_class.extend(res2[1000:1200])
    
train_path.extend(train[dir_name[3]])
train_class.extend(train_label[dir_name[3]])
test_path.extend(test[dir_name[3]])
test_class.extend(test_label[dir_name[3]])

# %%
df_train = pd.DataFrame(list(zip(train_path, train_class)),
               columns =['image_path', 'label'])

df_test = pd.DataFrame(list(zip(test_path, test_class)),
               columns =['image_path', 'label'])

# %% [markdown]
# ### Train/Test Distribution

# %%
df = df_train
lab = df['label']
dist = lab.value_counts()
sns.countplot(x = lab)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
df = df_test
lab = df['label']
dist = lab.value_counts()
sns.countplot(x = lab)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# ### Data generator, augmentations

# %%
train_aug = ImageDataGenerator(
    rotation_range=0.2,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,
    zoom_range=0.05,
    rescale = 1./255)

test_aug = ImageDataGenerator(
    rescale = 1./255)

train_generator= train_aug.flow_from_dataframe(
dataframe=df_train,
x_col="image_path",
y_col="label",
batch_size=32,
color_mode="rgb",
shuffle = True,
target_size = (224, 224),
class_mode="categorical")

test_generator= test_aug.flow_from_dataframe(
dataframe=df_test,
x_col="image_path",
y_col="label",
color_mode="rgb",
batch_size=32,
shuffle = False, #I set to False for classification report
target_size = (224, 224),
class_mode="categorical")
# Out:
# Found 3816 validated image filenames belonging to 4 classes.
# Found 706 validated image filenames belonging to 4 classes.

# %%
import matplotlib.pyplot as plt
plt.imshow(test_generator[0][0][2])

# %% [markdown]
# ### Adding Class weights

# %%
from sklearn.utils import class_weight
map_characters = train_generator.class_indices
print(map_characters)
class_weights = dict(zip(map_characters.values(), class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(train_class), 
                y=train_class))) 
print("Class Weights: ",class_weights)
# Out:
# {'CNV': 0, 'DME': 1, 'DRUSEN': 2, 'NORMAL': 3}
# Class Weights:  {0: 0.954, 1: 1.1691176470588236, 2: 0.954, 3: 0.954}

# %% [markdown]
# ### Build Model

# %%
from keras.layers import Activation,Dense, Dropout, Flatten, Conv2D, MaxPool2D,MaxPooling2D,AveragePooling2D, BatchNormalization
from keras.applications.vgg16 import VGG16
from keras.models import Model
from keras.applications.inception_v3 import InceptionV3

def generate_model(pretrained_model = 'vgg16', num_classes = 4):
    if pretrained_model == 'inceptionv3':
        weight_path = '../input/keras-pretrained-models/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'
        base_model = InceptionV3(weights = weight_path, include_top=False, input_shape=(224, 224, 3))
    else:
        weight_path = '../input/keras-pretrained-models/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'
        base_model = VGG16(weights = weight_path, include_top=False, input_shape=(224, 224, 3)) # Topless
    
    # Add top layer
    x = base_model.output
    x = Flatten()(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    
    # Train top layer
    for layer in base_model.layers:
        layer.trainable = False
        
    return model

model = generate_model("vgg16", 4)

# %% [markdown]
# ### Training model

# %%
rlr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss",
    factor=0.1,
    patience=4)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    patience=7, verbose=1)

model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

history = model.fit(train_generator, validation_data=test_generator, class_weight = class_weights, epochs = 50, callbacks = [rlr, early_stop])
# Out:
# Epoch 1/50
# 120/120 [==============================] - 82s 541ms/step - loss: 1.2315 - accuracy: 0.4900 - val_loss: 0.6005 - val_accuracy: 0.7890
# Epoch 2/50
# 120/120 [==============================] - 61s 512ms/step - loss: 0.6089 - accuracy: 0.7639 - val_loss: 0.6166 - val_accuracy: 0.7805
# Epoch 3/50
# 120/120 [==============================] - 61s 506ms/step - loss: 0.5846 - accuracy: 0.7678 - val_loss: 0.5689 - val_accuracy: 0.7875
# Epoch 4/50
# 120/120 [==============================] - 61s 511ms/step - loss: 0.4701 - accuracy: 0.8118 - val_loss: 0.5103 - val_accuracy: 0.8144
# Epoch 5/50
# 120/120 [==============================] - 61s 505ms/step - loss: 0.4179 - accuracy: 0.8432 - val_loss: 0.4618 - val_accuracy: 0.8343
# Epoch 6/50
# 120/120 [==============================] - 61s 506ms/step - loss: 0.3810 - accuracy: 0.8580 - val_loss: 0.4569 - val_accuracy: 0.8215
# Epoch 7/50
# 120/120 [==============================] - 61s 506ms/step - loss: 0.3649 - accuracy: 0.8641 - val_loss: 0.5100 - val_accuracy: 0.8286
# Epoch 8/50
# 120/120 [==============================] - 61s 511ms/step - loss: 0.3348 - accuracy: 0.8755 - val_loss: 0.4681 - val_accuracy: 0.8414
# Epoch 9/50
# 120/120 [==============================] - 61s 511ms/step - loss: 0.2890 - accuracy: 0.8919 - val_loss: 0.4286 - val_accuracy: 0.8442
# Epoch 10/50
# 120/120 [==============================] - 61s 511ms/step - loss: 0.3150 - accuracy: 0.8782 - val_loss: 0.5324 - val_accuracy: 0.8187
# Epoch 11/50
# 120/120 [==============================] - 62s 512ms/step - loss: 0.2754 - accuracy: 0.9016 - val_loss: 0.4260 - val_accuracy: 0.8499
# Epoch 12/50
# 120/120 [==============================] - 62s 513ms/step - loss: 0.2907 - accuracy: 0.8959 - val_loss: 0.4667 - val_accuracy: 0.8385
# Epoch 13/50
# 120/120 [==============================] - 61s 507ms/step - loss: 0.2253 - accuracy: 0.9212 - val_loss: 0.4974 - val_accuracy: 0.8258
# Epoch 14/50
# 120/120 [==============================] - 60s 499ms/step - loss: 0.2486 - accuracy: 0.9108 - val_loss: 0.4392 - val_accuracy: 0.8442
# Epoch 15/50
# 120/120 [==============================] - 61s 508ms/step - loss: 0.2466 - accuracy: 0.9058 - val_loss: 0.5323 - val_accuracy: 0.8187
# Epoch 16/50
# 120/120 [==============================] - 62s 518ms/step - loss: 0.1885 - accuracy: 0.9404 - val_loss: 0.4396 - val_accuracy: 0.8555
# Epoch 17/50
# 120/120 [==============================] - 62s 515ms/step - loss: 0.1725 - accuracy: 0.9491 - val_loss: 0.4428 - val_accuracy: 0.8484
# Epoch 18/50
# 120/120 [==============================] - 60s 503ms/step - loss: 0.1766 - accuracy: 0.9458 - val_loss: 0.4409 - val_accuracy: 0.8513
# Epoch 19/50
# 120/120 [==============================] - 60s 503ms/step - loss: 0.1679 - accuracy: 0.9510 - val_loss: 0.4304 - val_accuracy: 0.8555
# Epoch 20/50
# 120/120 [==============================] - 61s 511ms/step - loss: 0.1717 - accuracy: 0.9519 - val_loss: 0.4326 - val_accuracy: 0.8513
# Epoch 21/50
# 120/120 [==============================] - 60s 502ms/step - loss: 0.1736 - accuracy: 0.9473 - val_loss: 0.4343 - val_accuracy: 0.8484
# Epoch 22/50
# 120/120 [==============================] - 61s 505ms/step - loss: 0.1673 - accuracy: 0.9503 - val_loss: 0.4324 - val_accuracy: 0.8513
# Epoch 23/50
# 120/120 [==============================] - 61s 504ms/step - loss: 0.1745 - accuracy: 0.9504 - val_loss: 0.4355 - val_accuracy: 0.8484
# Epoch 00023: early stopping

# %% [markdown]
# ### Plot Accuracy and Loss Graphs

# %%
from PIL import Image

def infer_single_image(model, image_path, class_labels):
    # Load image
    img = Image.open(image_path).convert("RGB")
    img = img.resize((224, 224))
    img_arr = np.array(img) / 255.0
    img_arr = np.expand_dims(img_arr, axis=0)

    # Model prediction
    preds = model.predict(img_arr)[0]  # probabilities

    # Format JSON
    json_output = format_json_output(preds, class_labels, image_path)
    return json_output

# %%
def format_json_output(probs, class_labels, image_path):
    pred_idx = np.argmax(probs)
    pred_label = class_labels[pred_idx]
    pred_score = float(probs[pred_idx])

    output = {
        "model_name": "VGG16-OCT-Classifier",
        "version": "1.0.0",
        "timestamp": datetime.utcnow().isoformat() + "Z",
        "input_image": image_path,
        "prediction": {
            "label": pred_label,
            "score": pred_score,
            "class_probabilities": {
                class_labels[i]: float(probs[i])
                for i in range(len(class_labels))
            }
        }
    }
    return output

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ### Classification Report

# %%
class_labels = list(test_generator.class_indices.keys())

# Example: run inference on 10 test images
results = []

for path in test_path[:10]:  # only 10 images
    result_json = infer_single_image(model, path, class_labels)
    results.append(result_json)
    print(json.dumps(result_json, indent=2))
# Out:
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:36:35.921645Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-6990539-2.jpeg",
#   "prediction": {
#     "label": "NORMAL",
#     "score": 0.9753950238227844,
#     "class_probabilities": {
#       "CNV": 0.0023308543022722006,
#       "DME": 0.00017281202599406242,
#       "DRUSEN": 0.022101271897554398,
#       "NORMAL": 0.9753950238227844
#     }
#   }
# }
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:36:35.972909Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-9734808-42.jpeg",
#   "prediction": {
#     "label": "DRUSEN",
#     "score": 0.6651409864425659,
#     "class_probabilities": {
#       "CNV": 0.29405295848846436,
#       "DME": 0.015671977773308754,
#       "DRUSEN": 0.6651409864425659,
#       "NORMAL": 0.025134028866887093
#     }
#   }
# }
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:36:36.021229Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-7064008-21.jpeg",
#   "prediction": {
#     "label": "DRUSEN",
#     "score": 0.4686310291290283,
#     "class_probabilities": {
#       "CNV": 0.01072273962199688,
#       "DME": 0.25765278935432434,
#       "DRUSEN": 0.4686310291290283,
#       "NORMAL": 0.2629934251308441
#     }
#   }
# }
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:36:36.072496Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-6264369-2.jpeg",
#   "prediction": {
#     "label": "CNV",
#     "score": 0.9277780055999756,
#     "class_probabilities": {
#       "CNV": 0.9277780055999756,
#       "DME": 1.0909446245932486e-05,
#       "DRUSEN": 0.07220332324504852,
#       "NORMAL": 7.677203939238098e-06
#     }
#   }
# }
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:36:36.121152Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-6264369-10.jpeg",
#   "prediction": {
#     "label": "CNV",
#     "score": 0.8039631843566895,
#     "class_probabilities": {
#       "CNV": 0.8039631843566895,
#       "DME": 0.0015167978126555681,
#       "DRUSEN": 0.1874636709690094,
#       "NORMAL": 0.00705643929541111
#     }
#   }
# }
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:36:36.167937Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-9171051-8.jpeg",
#   "prediction": {
#     "label": "DRUSEN",
#     "score": 0.6682669520378113,
#     "class_probabilities": {
#       "CNV": 0.007537548430263996,
#       "DME": 0.008760076016187668,
#       "DRUSEN": 0.6682669520378113,
#       "NORMAL": 0.3154354393482208
#     }
#   }
# }
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:36:36.216143Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-5743416-33.jpeg",
#   "prediction": {
#     "label": "DRUSEN",
#     "score": 0.7565819025039673,
#     "class_probabilities": {
#       "CNV": 0.0007930013816803694,
#       "DME": 0.24221432209014893,
#       "DRUSEN": 0.7565819025039673,
#       "NORMAL": 0.0004106894484721124
#     }
#   }
# }
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:36:36.264763Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-9547888-53.jpeg",
#   "prediction": {
#     "label": "DRUSEN",
#     "score": 0.9138860106468201,
#     "class_probabilities": {
#       "CNV": 0.08578995615243912,
#       "DME": 7.154978811740875e-05,
#       "DRUSEN": 0.9138860106468201,
#       "NORMAL": 0.0002525828604120761
#     }
#   }
# }
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:36:36.315939Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-2541184-41.jpeg",
#   "prediction": {
#     "label": "DRUSEN",
#     "score": 0.9715789556503296,
#     "class_probabilities": {
#       "CNV": 0.027873100712895393,
#       "DME": 0.00040390572394244373,
#       "DRUSEN": 0.9715789556503296,
#       "NORMAL": 0.00014398593339137733
#     }
#   }
# }
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:36:36.367568Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-2233489-15.jpeg",
#   "prediction": {
#     "label": "NORMAL",
#     "score": 0.9805051684379578,
#     "class_probabilities": {
#       "CNV": 0.002014976227656007,
#       "DME": 0.0016847852384671569,
#       "DRUSEN": 0.015795087441802025,
#       "NORMAL": 0.9805051684379578
#     }
#   }
# }

# %%
print('\n', metrics.classification_report(y_true, y_pred_classes, target_names=class_labels), sep='')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6df7b3cd06f0> in <module>
# ----> 1 print('\n', metrics.classification_report(y_true, y_pred_classes, target_names=class_labels), sep='')
#
# NameError: name 'metrics' is not defined

# %% [markdown]
# ### ROC Curves

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score

def plot_roc_curves(y_true, y_pred, num_classes, class_labels):

    lb = LabelBinarizer()
    lb.fit(y_true)
    y_test = lb.transform(y_true)

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])


    # Plot all ROC curves
    for i in range(num_classes):
        fig, c_ax = plt.subplots(1,1, figsize = (6, 4))
        c_ax.plot(fpr[i], tpr[i],
                 label='ROC curve of class {0} (area = {1:0.4f})'
                 ''.format(class_labels[i], roc_auc[i]))
        c_ax.set_xlabel('False Positive Rate')
        c_ax.set_ylabel('True Positive Rate')
        c_ax.set_title('ROC curve of class {0}'.format(class_labels[i]))
        c_ax.legend(loc="lower right")
        plt.show()

    return roc_auc_score(y_test, y_pred)

# %%
print("ROS AUC score:", plot_roc_curves(y_true, y_pred, 4, class_labels))

# %% [markdown]
# ### Confusion matrix

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (5,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import confusion_matrix
import itertools
confusion_mtx = confusion_matrix(y_true, y_pred_classes)
plot_confusion_matrix(confusion_mtx, classes = list(map_characters.keys()))
plt.show()

# %%
model.save_weights("best_weights.h5")
print("Saved current model weights → best_weights.h5")
# Out:
# Saved current model weights → best_weights.h5

# %%
# ===============================
# 1. Load model architecture
# ===============================
model = generate_model("vgg16", 4)   # same architecture you trained

# ===============================
# 2. Load saved best weights
# ===============================
model.load_weights("best_weights.h5")
print("Loaded weights from best_weights.h5 successfully!\n")

# ===============================
# 3. Prepare class labels
# ===============================
class_labels = list(test_generator.class_indices.keys())

# ===============================
# 4. Run inference on 10 test images
# ===============================
import json

results = []

print("Running inference on 10 images...\n")

for img_path in test_path[:10]:      # first 10 images
    result_json = infer_single_image(model, img_path, class_labels)
    results.append(result_json)
    
    # Pretty print JSON
    print(json.dumps(result_json, indent=2))
    print("-" * 80)

# Save all inference results to a JSON file
with open("inference_results.json", "w") as f:
    json.dump(results, f, indent=2)

print("\nSaved all predictions → inference_results.json")
# Out:
# Loaded weights from best_weights.h5 successfully!
#
# Running inference on 10 images...
#
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:58:30.048142Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-6990539-2.jpeg",
#   "prediction": {
#     "label": "NORMAL",
#     "score": 0.9753950238227844,
#     "class_probabilities": {
#       "CNV": 0.0023308543022722006,
#       "DME": 0.00017281202599406242,
#       "DRUSEN": 0.022101271897554398,
#       "NORMAL": 0.9753950238227844
#     }
#   }
# }
# --------------------------------------------------------------------------------
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:58:30.107071Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-9734808-42.jpeg",
#   "prediction": {
#     "label": "DRUSEN",
#     "score": 0.6651409864425659,
#     "class_probabilities": {
#       "CNV": 0.29405295848846436,
#       "DME": 0.015671977773308754,
#       "DRUSEN": 0.6651409864425659,
#       "NORMAL": 0.025134028866887093
#     }
#   }
# }
# --------------------------------------------------------------------------------
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:58:30.162217Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-7064008-21.jpeg",
#   "prediction": {
#     "label": "DRUSEN",
#     "score": 0.4686310291290283,
#     "class_probabilities": {
#       "CNV": 0.01072273962199688,
#       "DME": 0.25765278935432434,
#       "DRUSEN": 0.4686310291290283,
#       "NORMAL": 0.2629934251308441
#     }
#   }
# }
# --------------------------------------------------------------------------------
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:58:30.216600Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-6264369-2.jpeg",
#   "prediction": {
#     "label": "CNV",
#     "score": 0.9277780055999756,
#     "class_probabilities": {
#       "CNV": 0.9277780055999756,
#       "DME": 1.0909446245932486e-05,
#       "DRUSEN": 0.07220332324504852,
#       "NORMAL": 7.677203939238098e-06
#     }
#   }
# }
# --------------------------------------------------------------------------------
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:58:30.270648Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-6264369-10.jpeg",
#   "prediction": {
#     "label": "CNV",
#     "score": 0.8039631843566895,
#     "class_probabilities": {
#       "CNV": 0.8039631843566895,
#       "DME": 0.0015167978126555681,
#       "DRUSEN": 0.1874636709690094,
#       "NORMAL": 0.00705643929541111
#     }
#   }
# }
# --------------------------------------------------------------------------------
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:58:30.330507Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-9171051-8.jpeg",
#   "prediction": {
#     "label": "DRUSEN",
#     "score": 0.6682669520378113,
#     "class_probabilities": {
#       "CNV": 0.007537548430263996,
#       "DME": 0.008760076016187668,
#       "DRUSEN": 0.6682669520378113,
#       "NORMAL": 0.3154354393482208
#     }
#   }
# }
# --------------------------------------------------------------------------------
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:58:30.385734Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-5743416-33.jpeg",
#   "prediction": {
#     "label": "DRUSEN",
#     "score": 0.7565819025039673,
#     "class_probabilities": {
#       "CNV": 0.0007930013816803694,
#       "DME": 0.24221432209014893,
#       "DRUSEN": 0.7565819025039673,
#       "NORMAL": 0.0004106894484721124
#     }
#   }
# }
# --------------------------------------------------------------------------------
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:58:30.442850Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-9547888-53.jpeg",
#   "prediction": {
#     "label": "DRUSEN",
#     "score": 0.9138860106468201,
#     "class_probabilities": {
#       "CNV": 0.08578995615243912,
#       "DME": 7.154978811740875e-05,
#       "DRUSEN": 0.9138860106468201,
#       "NORMAL": 0.0002525828604120761
#     }
#   }
# }
# --------------------------------------------------------------------------------
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:58:30.498080Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-2541184-41.jpeg",
#   "prediction": {
#     "label": "DRUSEN",
#     "score": 0.9715789556503296,
#     "class_probabilities": {
#       "CNV": 0.027873100712895393,
#       "DME": 0.00040390572394244373,
#       "DRUSEN": 0.9715789556503296,
#       "NORMAL": 0.00014398593339137733
#     }
#   }
# }
# --------------------------------------------------------------------------------
# {
#   "model_name": "VGG16-OCT-Classifier",
#   "version": "1.0.0",
#   "timestamp": "2025-12-11T13:58:30.553809Z",
#   "input_image": "/kaggle/input/kermany2018/OCT2017 /train/DRUSEN/DRUSEN-2233489-15.jpeg",
#   "prediction": {
#     "label": "NORMAL",
#     "score": 0.9805051684379578,
#     "class_probabilities": {
#       "CNV": 0.002014976227656007,
#       "DME": 0.0016847852384671569,
#       "DRUSEN": 0.015795087441802025,
#       "NORMAL": 0.9805051684379578
#     }
#   }
# }
# --------------------------------------------------------------------------------
#
# Saved all predictions → inference_results.json
